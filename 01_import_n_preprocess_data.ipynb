# %%
import wfdb as wf
import numpy as np 
from scipy.signal import butter, filtfilt
from glob import glob

# %% [markdown]
# # Methods definitions

# %%
def get_records():
    """ Get paths for data in data/mitdb/ directory """
    # There are 3 files for each record
    # *.atr is one of them
    paths = glob('data/mitdb/*.atr')

    # Get rid of the extension
    paths = [path[:-4] for path in paths]
    paths.sort()

    return paths

# Butterworth LowPass Filter
def butter_lowpass_filter(data, cutoff, fs, order):
    nyq = 0.5 * fs # Nyquist Frequency
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, data)
    return y

# %% [markdown]
# # Import and preprocess data

# %%
# Get available data files.
records = get_records()
print('Total files: ', len(records))

# using annotation to find the beats for data from mitdb
realbeats = ['N','L','R','B','A','a','J','S','V','r',
             'F','e','j','n','E','/','f','Q','?']

# Loop through each input file. Each file contains one
# record of ECG readings, sampled at 360 readings per
# second.
for path in records:
    pathpts = path.split('/')
    pathpts = pathpts[-1].split('\\')
    fn = pathpts[-1]
    print('Loading file:', path)

    # Read in the data
    record = wf.rdsamp(path)
    annotation = wf.rdann(path, 'atr')

    # Print some meta informations
    print('    Sampling frequency used for this record:', record[1].get('fs'))
    print('    Shape of loaded data array:', record[0].shape)
    print('    Number of loaded annotations:', len(annotation.num))
    
    # Get the ECG values from the file.
    data = record[0].transpose()

    # Get beat annotation to find the R-peaks
    # Generate the classifications based on the annotations.
    # 0.0 = undetermined
    # 1.0 = Normal beat
    # 2.0 = Left Bundle Branch Block beat (LBBB)
    # 3.0 = Right Bundle Branch Block beat (RBBB)
    # 4.0 = Premature Ventricular Contraction beat (PVC)
    # 5.0 = Premature Atrial Contraction beat (PAC)
    cat = np.array(annotation.symbol)
    rate = np.zeros_like(cat, dtype='float')
    rpeaks_sample = np.array([], dtype='int')

    for catid, catval in enumerate(cat):
        # Find rpeaks in the ECG data. Most should match with
        # the annotations.
        if (catval in realbeats): 
            rpeaks_sample = np.append(rpeaks_sample, annotation.sample[catid]) 

        if (catval == 'N'):
            rate[catid] = 1.0 # NORMAL
        elif (catval == 'L'):
            rate[catid] = 2.0 # LBBB
        elif (catval == 'R'):
            rate[catid] = 3.0 # RBBB
        elif (catval == 'V'):
            rate[catid] = 4.0 # PVC
        elif (catval == 'A'):
            rate[catid] = 5.0 # PAC

    rates = np.zeros_like(data[0], dtype='float')
    rates[annotation.sample] = rate

    # Process each channel separately (2 per input file).
    for channelid, channel in enumerate(data):
        chname = record[1].get('sig_name')[channelid]
        print('    ECG channel type:', chname)
        
        signals = butter_lowpass_filter(channel, cutoff=50, fs=360, order=2)
        
        beatstoremove = np.array([0], dtype='int')

        beats = np.empty_like(list(rpeaks_sample), dtype=object)
        
        # Split into individual heartbeats. For each heartbeat
        # record, append classification.
        for idx, idxval in enumerate(rpeaks_sample):
            firstround = idx == 0
            lastround = idx == len(beats) - 1

            # Skip first and last beat.
            if (firstround or lastround):
                beats[idx] = [0]
                beatstoremove = np.append(beatstoremove, idx)
                continue

            beats[idx] = signals[rpeaks_sample[idx-1]+50:rpeaks_sample[idx+1]-50]
            beats[idx] = beats[idx][:440]

            # Get the classification value that is on
            # or near the position of the rpeak index.
            fromidx = 0 if idxval < 10 else idxval - 10
            toidx = idxval + 10
            catval = rates[fromidx:toidx].max()

            # Skip beat if there is no classification.
            if (catval == 0.0):
                beatstoremove = np.append(beatstoremove, idx)
                continue

            # Normal beat is now classified as 0.0 and abnormal beat are 1.0 - 4.0
            catval = catval - 1.0

            # Normalize the readings to a 0-1 range
            beats[idx] = (beats[idx] - beats[idx].min()) / beats[idx].ptp()
        
            # Skipping records that are too long.
            if (beats[idx].size > 440):
                beatstoremove = np.append(beatstoremove, idx)
                continue

            # Pad with zeroes.
            zerocount = 440 - beats[idx].size
            beats[idx] = np.pad(beats[idx], (0, zerocount), 'constant', constant_values=(0.0, 0.0))

            # Append the classification to the beat data.
            beats[idx] = np.append(beats[idx], catval)

        # Remove first and last beats and the ones without classification.
        beats = np.delete(beats, beatstoremove)

        # Save to CSV file.
        savedata = np.array(list(beats[:]), dtype='float')
        outfn = 'data/ecg_beats/'+fn+'_'+chname+'.csv'
        print('    Generating ', outfn)
        with open(outfn, "wb") as fin:
            np.savetxt(fin, savedata, delimiter=",", fmt='%f')
# Out:
# Total files:  48
# Loading file: data/mitdb\100
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2274
#     ECG channel type: MLII
#     Generating  data/ecg_beats/100_MLII.csv
#     ECG channel type: V5
#     Generating  data/ecg_beats/100_V5.csv
# Loading file: data/mitdb\101
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1874
#     ECG channel type: MLII
#     Generating  data/ecg_beats/101_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/101_V1.csv
# Loading file: data/mitdb\102
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2192
#     ECG channel type: V5
#     Generating  data/ecg_beats/102_V5.csv
#     ECG channel type: V2
#     Generating  data/ecg_beats/102_V2.csv
# Loading file: data/mitdb\103
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2091
#     ECG channel type: MLII
#     Generating  data/ecg_beats/103_MLII.csv
#     ECG channel type: V2
#     Generating  data/ecg_beats/103_V2.csv
# Loading file: data/mitdb\104
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2311
#     ECG channel type: V5
#     Generating  data/ecg_beats/104_V5.csv
#     ECG channel type: V2
#     Generating  data/ecg_beats/104_V2.csv
# Loading file: data/mitdb\105
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2691
#     ECG channel type: MLII
#     Generating  data/ecg_beats/105_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/105_V1.csv
# Loading file: data/mitdb\106
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2098
#     ECG channel type: MLII
#     Generating  data/ecg_beats/106_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/106_V1.csv
# Loading file: data/mitdb\107
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2140
#     ECG channel type: MLII
#     Generating  data/ecg_beats/107_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/107_V1.csv
# Loading file: data/mitdb\108
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1824
#     ECG channel type: MLII
#     Generating  data/ecg_beats/108_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/108_V1.csv
# Loading file: data/mitdb\109
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2535
#     ECG channel type: MLII
#     Generating  data/ecg_beats/109_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/109_V1.csv
# Loading file: data/mitdb\111
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2133
#     ECG channel type: MLII
#     Generating  data/ecg_beats/111_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/111_V1.csv
# Loading file: data/mitdb\112
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2550
#     ECG channel type: MLII
#     Generating  data/ecg_beats/112_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/112_V1.csv
# Loading file: data/mitdb\113
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1796
#     ECG channel type: MLII
#     Generating  data/ecg_beats/113_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/113_V1.csv
# Loading file: data/mitdb\114
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1890
#     ECG channel type: V5
#     Generating  data/ecg_beats/114_V5.csv
#     ECG channel type: MLII
#     Generating  data/ecg_beats/114_MLII.csv
# Loading file: data/mitdb\115
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1962
#     ECG channel type: MLII
#     Generating  data/ecg_beats/115_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/115_V1.csv
# Loading file: data/mitdb\116
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2421
#     ECG channel type: MLII
#     Generating  data/ecg_beats/116_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/116_V1.csv
# Loading file: data/mitdb\117
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1539
#     ECG channel type: MLII
#     Generating  data/ecg_beats/117_MLII.csv
#     ECG channel type: V2
#     Generating  data/ecg_beats/117_V2.csv
# Loading file: data/mitdb\118
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2301
#     ECG channel type: MLII
#     Generating  data/ecg_beats/118_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/118_V1.csv
# Loading file: data/mitdb\119
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2094
#     ECG channel type: MLII
#     Generating  data/ecg_beats/119_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/119_V1.csv
# Loading file: data/mitdb\121
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1876
#     ECG channel type: MLII
#     Generating  data/ecg_beats/121_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/121_V1.csv
# Loading file: data/mitdb\122
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2479
#     ECG channel type: MLII
#     Generating  data/ecg_beats/122_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/122_V1.csv
# Loading file: data/mitdb\123
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1519
#     ECG channel type: MLII
#     Generating  data/ecg_beats/123_MLII.csv
#     ECG channel type: V5
#     Generating  data/ecg_beats/123_V5.csv
# Loading file: data/mitdb\124
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1634
#     ECG channel type: MLII
#     Generating  data/ecg_beats/124_MLII.csv
#     ECG channel type: V4
#     Generating  data/ecg_beats/124_V4.csv
# Loading file: data/mitdb\200
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2792
#     ECG channel type: MLII
#     Generating  data/ecg_beats/200_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/200_V1.csv
# Loading file: data/mitdb\201
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2039
#     ECG channel type: MLII
#     Generating  data/ecg_beats/201_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/201_V1.csv
# Loading file: data/mitdb\202
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2146
#     ECG channel type: MLII
#     Generating  data/ecg_beats/202_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/202_V1.csv
# Loading file: data/mitdb\203
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3108
#     ECG channel type: MLII
#     Generating  data/ecg_beats/203_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/203_V1.csv
# Loading file: data/mitdb\205
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2672
#     ECG channel type: MLII
#     Generating  data/ecg_beats/205_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/205_V1.csv
# Loading file: data/mitdb\207
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2385
#     ECG channel type: MLII
#     Generating  data/ecg_beats/207_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/207_V1.csv
# Loading file: data/mitdb\208
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3040
#     ECG channel type: MLII
#     Generating  data/ecg_beats/208_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/208_V1.csv
# Loading file: data/mitdb\209
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3052
#     ECG channel type: MLII
#     Generating  data/ecg_beats/209_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/209_V1.csv
# Loading file: data/mitdb\210
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2685
#     ECG channel type: MLII
#     Generating  data/ecg_beats/210_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/210_V1.csv
# Loading file: data/mitdb\212
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2763
#     ECG channel type: MLII
#     Generating  data/ecg_beats/212_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/212_V1.csv
# Loading file: data/mitdb\213
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3294
#     ECG channel type: MLII
#     Generating  data/ecg_beats/213_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/213_V1.csv
# Loading file: data/mitdb\214
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2297
#     ECG channel type: MLII
#     Generating  data/ecg_beats/214_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/214_V1.csv
# Loading file: data/mitdb\215
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3400
#     ECG channel type: MLII
#     Generating  data/ecg_beats/215_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/215_V1.csv
# Loading file: data/mitdb\217
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2280
#     ECG channel type: MLII
#     Generating  data/ecg_beats/217_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/217_V1.csv
# Loading file: data/mitdb\219
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2312
#     ECG channel type: MLII
#     Generating  data/ecg_beats/219_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/219_V1.csv
# Loading file: data/mitdb\220
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2069
#     ECG channel type: MLII
#     Generating  data/ecg_beats/220_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/220_V1.csv
# Loading file: data/mitdb\221
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2462
#     ECG channel type: MLII
#     Generating  data/ecg_beats/221_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/221_V1.csv
# Loading file: data/mitdb\222
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2634
#     ECG channel type: MLII
#     Generating  data/ecg_beats/222_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/222_V1.csv
# Loading file: data/mitdb\223
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2643
#     ECG channel type: MLII
#     Generating  data/ecg_beats/223_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/223_V1.csv
# Loading file: data/mitdb\228
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2141
#     ECG channel type: MLII
#     Generating  data/ecg_beats/228_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/228_V1.csv
# Loading file: data/mitdb\230
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2466
#     ECG channel type: MLII
#     Generating  data/ecg_beats/230_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/230_V1.csv
# Loading file: data/mitdb\231
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2011
#     ECG channel type: MLII
#     Generating  data/ecg_beats/231_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/231_V1.csv
# Loading file: data/mitdb\232
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1816
#     ECG channel type: MLII
#     Generating  data/ecg_beats/232_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/232_V1.csv
# Loading file: data/mitdb\233
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3152
#     ECG channel type: MLII
#     Generating  data/ecg_beats/233_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/233_V1.csv
# Loading file: data/mitdb\234
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2764
#     ECG channel type: MLII
#     Generating  data/ecg_beats/234_MLII.csv
#     ECG channel type: V1
#     Generating  data/ecg_beats/234_V1.csv
